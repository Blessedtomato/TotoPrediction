# %% [markdown]
# <a href="https://colab.research.google.com/github/Blessedtomato/TotoPrediction/blob/main/Toto3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, Dropout

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Xisiqomelir/xisiqo_datadump/main/ToTo.csv")

# %%
df.head()
# Out:
#    Draw        Date  Winning Number 1   2   3   4   5   6  Additional Number   \
# 0  3884  2023-07-06                13  16  28  34  38  40                  47
# 1  3883  2023-07-03                14  30  34  40  45  49                  12
# 2  3882  2023-06-29                 5  15  16  30  37  46                  49
# 3  3881  2023-06-26                 4   5  17  28  39  44                  31
# 4  3880  2023-06-22                 3   9  28  32  37  46                   7
#
#   From Last  ...  Division 3 Winners  Division 3 Prize  Division 4 Winners  \
# 0     34,40  ...               147.0            1666.0               263.0
# 1        30  ...                85.0            2223.0               235.0
# 2         5  ...               515.0            1661.0              1208.0
# 3        28  ...               237.0            1741.0               531.0
# 4  28,32,46  ...               112.0            2163.0               358.0
#
#    Division 4 Prize  Division 5 Winners  Division 5 Prize  Division 6 Winners  \
# 0             508.0              6591.0              50.0              7890.0
# 1             439.0              4664.0              50.0              6423.0
# 2             387.0             25404.0              50.0             33315.0
# 3             424.0             12396.0              50.0             16290.0
# 4             369.0              6596.0              50.0             11867.0
#
#    Division 6 Prize  Division 7 Winners  Division 7 Prize
# 0              25.0            121282.0              10.0
# 1              25.0             87982.0              10.0
# 2              25.0            475093.0              10.0
# 3              25.0            232715.0              10.0
# 4              25.0            125106.0              10.0
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1544 entries, 0 to 1543
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Draw                1544 non-null   int64
#  1   Date                1544 non-null   object
#  2   Winning Number 1    1544 non-null   int64
#  3   2                   1544 non-null   int64
#  4   3                   1544 non-null   int64
#  5   4                   1544 non-null   int64
#  6   5                   1544 non-null   int64
#  7   6                   1544 non-null   int64
#  8   Additional Number   1544 non-null   int64
#  9   From Last           915 non-null    object
#  10  Same As Day         208 non-null    float64
#  11  Odd                 1544 non-null   int64
#  12  Even                1544 non-null   int64
#  13   1-10               1544 non-null   int64
#  14   11-20              1544 non-null   int64
#  15   21-30              1544 non-null   int64
#  16   31-40              1544 non-null   int64
#  17   41-50              1544 non-null   int64
#  18  Division 1 Winners  1232 non-null   float64
#  19  Division 1 Prize    1232 non-null   float64
#  20  Division 2 Winners  1232 non-null   float64
#  21  Division 2 Prize    1232 non-null   float64
#  22  Division 3 Winners  1232 non-null   float64
#  23  Division 3 Prize    1232 non-null   float64
#  24  Division 4 Winners  1232 non-null   float64
#  25  Division 4 Prize    1232 non-null   float64
#  26  Division 5 Winners  1232 non-null   float64
#  27  Division 5 Prize    1232 non-null   float64
#  28  Division 6 Winners  1232 non-null   float64
#  29  Division 6 Prize    1232 non-null   float64
#  30  Division 7 Winners  890 non-null    float64
#  31  Division 7 Prize    890 non-null    float64
# dtypes: float64(15), int64(15), object(2)
# memory usage: 386.1+ KB

# %%
df.drop(['From Last', 'Same As Day', 'Odd', 'Even', ' 1-10', ' 11-20', ' 21-30', ' 31-40', ' 41-50', 'Division 1 Winners', 'Division 1 Prize', 'Division 2 Winners', 'Division 2 Prize', 'Division 3 Winners', 'Division 3 Prize', 'Division 4 Winners', 'Division 4 Prize', 'Division 5 Winners', 'Division 5 Prize', 'Division 6 Winners', 'Division 6 Prize', 'Division 7 Winners', 'Division 7 Prize', 'Date','Draw'], axis=1, inplace=True)
df.head()
# Out:
#    Winning Number 1   2   3   4   5   6  Additional Number
# 0                13  16  28  34  38  40                  47
# 1                14  30  34  40  45  49                  12
# 2                 5  15  16  30  37  46                  49
# 3                 4   5  17  28  39  44                  31
# 4                 3   9  28  32  37  46                   7

# %%
df = df[:-654]
#To remove draws before 9/10/2014 because they are 45 numbers before

# %%
print(df.shape)
# Out:
# (890, 7)

# %%
df.describe()
# Out:
#        Winning Number 1           2           3           4           5  \
# count        890.000000  890.000000  890.000000  890.000000  890.000000
# mean           6.823596   14.055056   21.270787   28.601124   35.632584
# std            5.564764    7.350941    7.960090    8.061867    7.301236
# min            1.000000    2.000000    4.000000    7.000000   14.000000
# 25%            3.000000    9.000000   15.000000   23.000000   31.000000
# 50%            5.000000   13.000000   21.000000   29.000000   37.000000
# 75%            9.000000   19.000000   27.000000   35.000000   41.000000
# max           33.000000   38.000000   43.000000   47.000000   48.000000
#
#                 6  Additional Number
# count  890.000000          890.000000
# mean    43.100000           25.334831
# std      5.420257           14.228974
# min     19.000000            1.000000
# 25%     40.000000           13.000000
# 50%     45.000000           26.000000
# 75%     47.000000           37.000000
# max     49.000000           49.000000

# %%
scaler = StandardScaler().fit(df.values)
transformed_dataset = scaler.transform(df.values)
transformed_df = pd.DataFrame(data=transformed_dataset, index=df.index)

# %%
transformed_df.head()
# Out:
#           0         1         2         3         4         5         6
# 0  1.110537  0.264733  0.845844  0.670057  0.324431 -0.572250  1.523465
# 1  1.290340  2.170322  1.600028  1.414720  1.283712  1.089121 -0.937687
# 2 -0.327888  0.128620 -0.662524  0.173615  0.187391  0.535331  1.664103
# 3 -0.507691 -1.232515 -0.536827 -0.074606  0.461471  0.166137  0.398367
# 4 -0.687495 -0.688061  0.845844  0.421836  0.187391  0.535331 -1.289281

# %%
# All our games
number_of_rows = df.values.shape[0]
number_of_rows
# Out:
# 890

# %%
# Amount of games we need to take into consideration for prediction
window_length = 30
window_length
# Out:
# 30

# %%
# Balls counts
number_of_features = df.values.shape[1]
number_of_features
# Out:
# 7

# %%
X = np.empty([ number_of_rows - window_length, window_length, number_of_features], dtype=float)
y = np.empty([ number_of_rows - window_length, number_of_features], dtype=float)
for i in range(0, number_of_rows-window_length):
    X[i] = transformed_df.iloc[i : i+window_length, 0 : number_of_features]
    y[i] = transformed_df.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
X.shape
# Out:
# (860, 30, 7)

# %%
y.shape
# Out:
# (860, 7)

# %%
X[0]
# Out:
# array([[ 1.11053721,  0.2647331 ,  0.84584431,  0.6700572 ,  0.32443094,
#         -0.57225014,  1.52346549],
#        [ 1.29034039,  2.17032199,  1.60002843,  1.41472015,  1.28371178,
#        [ 0.75093084,  0.94530056,  1.09723902,  0.29772573, -0.36076966,
#         -0.94144378, -0.09386355],
#        [ 0.21152128, -0.55194786, -1.16531331, -0.44693722, -0.49780979,
#         -0.94144378, -0.37513817],
#        [-0.1480851 , -0.96028834,  1.22293637,  1.66294113,  1.4207519 ,
#          0.71992759,  0.11709241],
#        [ 1.11053721,  1.76198152,  0.84584431,  1.66294113,  1.14667166,
#          0.35073396, -1.71119259],
#        [ 0.93073402,  1.62586802,  1.60002843,  1.29060966,  0.7355513 ,
#          1.08912123, -0.65641278],
#        [-1.04710103, -1.36862882, -0.53682656, -0.07460574,  1.00963154,
#          0.35073396,  0.25772972],
#        [ 1.29034039,  0.94530056,  0.59444961,  0.04950475,  0.18739082,
#         -0.57225014, -1.28928067]])

# %%
y[1]
# Out:
# array([ 0.03171809, -0.82417485, -0.78822126, -0.19871624, -0.22372954,
#        -0.94144378,  0.82027895])

# %%
model = Sequential()

# %%
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = True)))

# %%
model.add(Dropout(0.2))

# %%
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = True)))

# %%
model.add(Dropout(0.2))

# %%
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = True)))

# %%
model.add(Bidirectional(LSTM(240, input_shape = (window_length, number_of_features), return_sequences = False)))

# %%
model.add(Dense(59))

# %%
model.add(Dense(number_of_features))

# %%
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=X, y=y, batch_size=600, epochs=600, verbose=2)
# Out:
# Epoch 1/600
# 2/2 - 48s - loss: 1.0013 - accuracy: 0.1791 - 48s/epoch - 24s/step
# Epoch 2/600
# 2/2 - 16s - loss: 0.9966 - accuracy: 0.1988 - 16s/epoch - 8s/step
# Epoch 3/600
# 2/2 - 17s - loss: 0.9935 - accuracy: 0.2093 - 17s/epoch - 9s/step
# Epoch 4/600
# 2/2 - 18s - loss: 0.9922 - accuracy: 0.2140 - 18s/epoch - 9s/step
# Epoch 5/600
# 2/2 - 16s - loss: 0.9910 - accuracy: 0.2070 - 16s/epoch - 8s/step
# Epoch 6/600
# 2/2 - 17s - loss: 0.9893 - accuracy: 0.2233 - 17s/epoch - 8s/step
# Epoch 7/600
# 2/2 - 17s - loss: 0.9885 - accuracy: 0.2279 - 17s/epoch - 8s/step
# Epoch 8/600
# 2/2 - 16s - loss: 0.9869 - accuracy: 0.2267 - 16s/epoch - 8s/step
# Epoch 9/600
# 2/2 - 16s - loss: 0.9857 - accuracy: 0.2128 - 16s/epoch - 8s/step
# Epoch 10/600
# 2/2 - 17s - loss: 0.9849 - accuracy: 0.2233 - 17s/epoch - 8s/step
# Epoch 11/600
# 2/2 - 17s - loss: 0.9838 - accuracy: 0.2244 - 17s/epoch - 8s/step
# Epoch 12/600
# 2/2 - 16s - loss: 0.9825 - accuracy: 0.2244 - 16s/epoch - 8s/step
# Epoch 13/600
# 2/2 - 16s - loss: 0.9818 - accuracy: 0.2302 - 16s/epoch - 8s/step
# Epoch 14/600
# 2/2 - 16s - loss: 0.9810 - accuracy: 0.2419 - 16s/epoch - 8s/step
# Epoch 15/600
# 2/2 - 17s - loss: 0.9801 - accuracy: 0.2581 - 17s/epoch - 8s/step
# Epoch 16/600
# 2/2 - 16s - loss: 0.9791 - accuracy: 0.2419 - 16s/epoch - 8s/step
# Epoch 17/600
# 2/2 - 16s - loss: 0.9780 - accuracy: 0.2570 - 16s/epoch - 8s/step
# Epoch 18/600
# 2/2 - 16s - loss: 0.9768 - accuracy: 0.2453 - 16s/epoch - 8s/step
# Epoch 19/600
# 2/2 - 17s - loss: 0.9763 - accuracy: 0.2500 - 17s/epoch - 8s/step
# Epoch 20/600
# 2/2 - 16s - loss: 0.9756 - accuracy: 0.2500 - 16s/epoch - 8s/step
# Epoch 21/600
# 2/2 - 16s - loss: 0.9749 - accuracy: 0.2430 - 16s/epoch - 8s/step
# Epoch 22/600
# 2/2 - 16s - loss: 0.9738 - accuracy: 0.2419 - 16s/epoch - 8s/step
# Epoch 23/600
# 2/2 - 17s - loss: 0.9733 - accuracy: 0.2384 - 17s/epoch - 9s/step
# Epoch 24/600
# 2/2 - 16s - loss: 0.9721 - accuracy: 0.2430 - 16s/epoch - 8s/step
# Epoch 25/600
# 2/2 - 16s - loss: 0.9710 - accuracy: 0.2430 - 16s/epoch - 8s/step
# Epoch 26/600
# 2/2 - 16s - loss: 0.9708 - accuracy: 0.2465 - 16s/epoch - 8s/step
# Epoch 27/600
# 2/2 - 17s - loss: 0.9687 - accuracy: 0.2477 - 17s/epoch - 9s/step
# Epoch 28/600
# 2/2 - 16s - loss: 0.9687 - accuracy: 0.2477 - 16s/epoch - 8s/step
# Epoch 29/600
# 2/2 - 16s - loss: 0.9672 - accuracy: 0.2523 - 16s/epoch - 8s/step
# Epoch 30/600
# 2/2 - 16s - loss: 0.9662 - accuracy: 0.2535 - 16s/epoch - 8s/step
# Epoch 31/600
# 2/2 - 17s - loss: 0.9652 - accuracy: 0.2581 - 17s/epoch - 9s/step
# Epoch 32/600
# 2/2 - 16s - loss: 0.9637 - accuracy: 0.2523 - 16s/epoch - 8s/step
# Epoch 33/600
# 2/2 - 16s - loss: 0.9626 - accuracy: 0.2500 - 16s/epoch - 8s/step
# Epoch 34/600
# 2/2 - 16s - loss: 0.9615 - accuracy: 0.2465 - 16s/epoch - 8s/step
# Epoch 35/600
# 2/2 - 17s - loss: 0.9605 - accuracy: 0.2442 - 17s/epoch - 9s/step
# Epoch 36/600
# 2/2 - 16s - loss: 0.9596 - accuracy: 0.2419 - 16s/epoch - 8s/step
# Epoch 37/600
# 2/2 - 16s - loss: 0.9578 - accuracy: 0.2523 - 16s/epoch - 8s/step
# Epoch 38/600
# 2/2 - 16s - loss: 0.9566 - accuracy: 0.2419 - 16s/epoch - 8s/step
# Epoch 39/600
# 2/2 - 17s - loss: 0.9553 - accuracy: 0.2430 - 17s/epoch - 9s/step
# Epoch 40/600
# 2/2 - 16s - loss: 0.9536 - accuracy: 0.2558 - 16s/epoch - 8s/step
# Epoch 41/600
# 2/2 - 16s - loss: 0.9508 - accuracy: 0.2616 - 16s/epoch - 8s/step
# Epoch 42/600
# 2/2 - 16s - loss: 0.9501 - accuracy: 0.2698 - 16s/epoch - 8s/step
# Epoch 43/600
# 2/2 - 17s - loss: 0.9484 - accuracy: 0.2767 - 17s/epoch - 9s/step
# Epoch 44/600
# 2/2 - 16s - loss: 0.9473 - accuracy: 0.2802 - 16s/epoch - 8s/step
# Epoch 45/600
# 2/2 - 16s - loss: 0.9436 - accuracy: 0.2733 - 16s/epoch - 8s/step
# Epoch 46/600
# 2/2 - 16s - loss: 0.9416 - accuracy: 0.2698 - 16s/epoch - 8s/step
# Epoch 47/600
# 2/2 - 17s - loss: 0.9412 - accuracy: 0.2721 - 17s/epoch - 8s/step
# Epoch 48/600
# 2/2 - 16s - loss: 0.9383 - accuracy: 0.2791 - 16s/epoch - 8s/step
# Epoch 49/600
# 2/2 - 16s - loss: 0.9352 - accuracy: 0.2698 - 16s/epoch - 8s/step
# Epoch 50/600
# 2/2 - 16s - loss: 0.9337 - accuracy: 0.2686 - 16s/epoch - 8s/step
# Epoch 51/600
# 2/2 - 16s - loss: 0.9300 - accuracy: 0.2756 - 16s/epoch - 8s/step
# Epoch 52/600
# 2/2 - 17s - loss: 0.9280 - accuracy: 0.2860 - 17s/epoch - 9s/step
# Epoch 53/600
# 2/2 - 16s - loss: 0.9260 - accuracy: 0.2756 - 16s/epoch - 8s/step
# Epoch 54/600
# 2/2 - 16s - loss: 0.9262 - accuracy: 0.2802 - 16s/epoch - 8s/step
# Epoch 55/600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-a556fbc4b113> in <cell line: 1>()
# ----> 1 model.fit(x=X, y=y, batch_size=600, epochs=600, verbose=2)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
to_predict = df.head(15)
to_predict

# %%
to_predict = np.array(to_predict)
to_predict

# %%
scaled_to_predict = scaler.transform(to_predict)
scaled_to_predict

# %%
y_pred = model.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])
